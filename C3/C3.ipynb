# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0,np.pi,200)
plt.plot(x,np.tan(x))

# %% [markdown]
# # Euler

# %%
def func(x,y):
    return y**2+1

def E_Method(xi, yi, h=0.01, steps=100):
    '''
    h = step size (default = 0.01), steps = number of steps to go for loop (default = 100). 
    '''
    x_vals = [xi]
    y_vals = [yi]
    
    for i in range(steps):
        y_new = yi + h * func(x=0,y=yi)
        x_new = xi + h

        yi = y_new
        xi = x_new

        x_vals.append(xi)
        y_vals.append(yi)

    return np.array(x_vals), np.array(y_vals)

# %%
x_vals, y_vals = E_Method(xi=0,yi=0)
plt.plot(x_vals,y_vals, label="Euler approx")
plt.plot(x_vals,np.tan(x_vals),label = "tan(x)")
plt.legend()

# %%
x_vals, y_vals = E_Method(xi=0,yi=0,steps=200) #this breaks because the value of y gets way too large
plt.plot(x_vals,y_vals, label="Euler approx")
plt.plot(x_vals,np.tan(x_vals),label = "tan(x)")
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 x_vals, y_vals = E_Method(xi=0,yi=0,steps=200) #this breaks because the value of y gets way too large
#       2 plt.plot(x_vals,y_vals, label="Euler approx")
#       3 plt.plot(x_vals,np.tan(x_vals),label = "tan(x)")
#
# Cell In[3], line 12, in E_Method(xi, yi, h, steps)
#       9 y_vals = [yi]
#      11 for i in range(steps):
# ---> 12     y_new = yi + h * func(x=0,y=yi)
#      13     x_new = xi + h
#      15     yi = y_new
#
# Cell In[3], line 2, in func(x, y)
#       1 def func(x,y):
# ----> 2     return y**2+1
#
# OverflowError: (34, 'Result too large')

# %%
x_vals, y_vals = E_Method(xi=0,yi=0,steps=150)
plt.plot(x_vals,y_vals, label="Euler approx")
plt.plot(x_vals,np.tan(x_vals),label = "tan(x)")
plt.legend()

# %%
x_vals, y_vals = E_Method(xi=0,yi=0,steps=170)
plt.plot(x_vals,y_vals, label="Euler approx")
plt.plot(x_vals,np.tan(x_vals),label = "tan(x)")
plt.legend()

# %%
x_vals, y_vals = E_Method(xi=0,yi=0,steps=170)
plt.plot(x_vals,y_vals, label="Euler approx")
plt.plot(x_vals,np.tan(x_vals),label = "tan(x)")
plt.legend()
plt.xlim(1.64,1.70)
# Out:
# (1.64, 1.7)

# %%
ran_con = [0.1,0.01,0.001,0.0001,1e-5,1e-6]

for i in ran_con:
    x_vals, y_vals = E_Method(xi=0,yi=0,h=i,steps=150)
    plt.plot(x_vals,y_vals, label="Euler approx")

plt.plot(x_vals,np.tan(x_vals),label = "tan(x)")
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# Cell In[12], line 4
#       1 ran_con = [0.1,0.01,0.001,0.0001,1e-5,1e-6]
#       3 for i in ran_con:
# ----> 4     x_vals, y_vals = E_Method(xi=0,yi=0,h=i,steps=150)
#       5     plt.plot(x_vals,y_vals, label="Euler approx")
#       7 plt.plot(x_vals,np.tan(x_vals),label = "tan(x)")
#
# Cell In[3], line 12, in E_Method(xi, yi, h, steps)
#       9 y_vals = [yi]
#      11 for i in range(steps):
# ---> 12     y_new = yi + h * func(x=0,y=yi)
#      13     x_new = xi + h
#      15     yi = y_new
#
# Cell In[3], line 2, in func(x, y)
#       1 def func(x,y):
# ----> 2     return y**2+1
#
# OverflowError: (34, 'Result too large')

# %%
x_vals, y_vals = E_Method(xi=0,yi=0,h=0.01,steps=1500)
plt.plot(x_vals,y_vals, label="Euler approx")
plt.plot(x_vals,np.tan(x_vals),label = "tan(x)")
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 x_vals, y_vals = E_Method(xi=0,yi=0,h=0.01,steps=1500)
#       2 plt.plot(x_vals,y_vals, label="Euler approx")
#       3 plt.plot(x_vals,np.tan(x_vals),label = "tan(x)")
#
# Cell In[3], line 12, in E_Method(xi, yi, h, steps)
#       9 y_vals = [yi]
#      11 for i in range(steps):
# ---> 12     y_new = yi + h * func(x=0,y=yi)
#      13     x_new = xi + h
#      15     yi = y_new
#
# Cell In[3], line 2, in func(x, y)
#       1 def func(x,y):
# ----> 2     return y**2+1
#
# OverflowError: (34, 'Result too large')

# %%
x_vals, y_vals = E_Method(xi=0,yi=0,h=0.001,steps=1500)
plt.plot(x_vals,y_vals, label="Euler approx")
plt.plot(x_vals,np.tan(x_vals),label = "tan(x)")
plt.legend()

# %% [markdown]
# # RK

# %%
def RK4(xi, yi, h=0.01, steps=100):
    '''
    h = step size (default = 0.01), steps = number of steps to go for loop (default = 100). 
    '''
    
    x_vals = [xi]
    y_vals = [yi]

    for i in range(steps):
        k1 = func(xi,yi)
        k2 = func(xi+(h/2), yi+k1*(h/2))
        k3 = func(xi+(h/2),yi+k2*(h/2))
        k4 = func(xi+h,yi+k3*h)
        
        y_new = yi + (h/6)*(k1+2*k2+2*k3+k4)
        x_new = xi + h

        yi = y_new
        xi = x_new

        x_vals.append(xi)
        y_vals.append(yi)

    return np.array(x_vals), np.array(y_vals)

# %%
x_vals, y_vals = RK4(xi=0,yi=0)
plt.plot(x_vals,np.tan(x_vals),label = "tan(x)")
plt.plot(x_vals,y_vals, label="Euler approx")
plt.legend()

# %%
x_vals, y_vals = RK4(xi=0,yi=0,steps=200)
plt.plot(x_vals,np.tan(x_vals),label = "tan(x)")
plt.plot(x_vals,y_vals, label="Euler approx")
plt.legend()

# %%
x_vals, y_vals = RK4(xi=0,yi=0,steps=150)
plt.plot(x_vals,np.tan(x_vals),label = "tan(x)")
plt.plot(x_vals,y_vals, label="Euler approx")
plt.legend()

# %%
x_vals, y_vals = RK4(xi=0,yi=0,h=0.001,steps=1500)
plt.plot(x_vals,y_vals, label="Euler approx")
plt.plot(x_vals,np.tan(x_vals),label = "tan(x)")
plt.legend()

# %% [markdown]
# Continuing on......

# %%
def vel_dist(T=10000):
    '''
    For Hydrogen atoms
    '''
    k = 
    m = 
    return (m/(2*np.pi*k*T))**(3/2)*4*np.pi*(v**2)*np.exp(-(m*v**2)/(2*k*T))
